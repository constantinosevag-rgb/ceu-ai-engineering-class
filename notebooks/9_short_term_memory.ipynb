# %% [markdown]
# # Short-Term Memory

# %%
from agents import Agent, Runner, SQLiteSession, trace
from setup import bedrock_tool
# Out:
# ✅ AWS credentials found
# ✅ OpenAI credentials found
# ✅ EXA credentials found

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant comparing how healthy different foods are.
    If you answer, give a list of how healthy the foods are with a score from 1 to 10. Order by: healtiest food comes first.

    Example:
    Q: Compare X and Y
    A: X is healtier as Y.
    1) X: 8/10 - Very healthy but high in fructose
    2) Y: 3/10 - High in sugar and fat
    """,
    model="litellm/bedrock/eu.amazon.nova-lite-v1:0",
)

# %% [markdown]
# ## No Memory

# %%
with trace("Compare without Memory") as t:
    result = await Runner.run(nutrition_agent, "Which is healthier, bananas or lollipop?")

print(f"Output: {result.final_output}")
print(f"\nTrace URL: https://platform.openai.com/logs/trace?trace_id={t.trace_id}")
# Out:
# Output: A: Bananas are healthier than lollipops.
#
# 1) Bananas: 9/10 - High in essential vitamins (like Vitamin C and B6), minerals (like potassium), fiber, and antioxidants. They provide natural sugars and energy.
# 2) Lollipops: 1/10 - High in refined sugars and artificial ingredients, with no nutritional value. They can contribute to cavities and provide empty calories.
#
# Trace URL: https://platform.openai.com/logs/trace?trace_id=trace_439f66bbe8d440b2890b0174b2880449

# %%
with trace("Add Apple - without Memory") as t:
    result = await Runner.run(nutrition_agent, "Add apples to the comparison")

print(f"Output: {result.final_output}")
print(f"\nTrace URL: https://platform.openai.com/logs/trace?trace_id={t.trace_id}")
# Out:
# Output: Sure, let's compare apples with a few other foods and rank them based on their health scores from 1 to 10, with 10 being the healthiest.
#
# ### Comparison: Apples vs. Other Foods
#
# 1) **Apples: 9/10**
#    - Apples are rich in fiber, particularly soluble fiber, which helps lower cholesterol and regulate blood sugar levels. They also contain antioxidants like quercetin and vitamin C, which can help reduce the risk of chronic diseases.
#
# 2) **Blueberries: 8.5/10**
#    - Blueberries are packed with antioxidants, vitamins, and fiber. They have been shown to support brain health, reduce inflammation, and improve heart health.
#
# 3) **Spinach: 8/10**
#    - Spinach is a nutrient powerhouse, providing vitamins A, C, and K, as well as iron, calcium, and antioxidants. It's great for bone health, immune function, and reducing oxidative stress.
#
# 4) **Salmon: 7.5/10**
#    - Salmon is rich in omega-3 fatty acids, which are excellent for heart health, reducing inflammation, and supporting brain function. It also provides high-quality protein and essential vitamins like D and B12.
#
# 5) **Avocado: 7/10**
#    - Avocados are high in healthy monounsaturated fats, fiber, and a variety of vitamins and minerals, including potassium and vitamin K. They are great for heart health and can help manage cholesterol levels.
#
# 6) **Oats: 6.5/10**
#    - Oats are a whole grain rich in soluble fiber, which helps lower cholesterol and stabilize blood sugar levels. They also contain important vitamins and minerals like manganese and phosphorus.
#
# 7) **Peanut Butter: 6/10**
#    - While peanut butter is healthy in moderation, providing protein, healthy fats, and various nutrients, it is also high in calories and can be easy to overeat.
#
# 8) **Cheese: 5/10**
#    - Cheese can be part of a healthy diet in moderation, providing calcium and protein. However, it can also be high in saturated fat and sodium, so it should be consumed in limited amounts.
#
# 9) **Candy: 1/10**
#    - Candy is high in sugar and provides little to no nutritional value. It can contribute to weight gain, tooth decay, and an increased risk of chronic diseases.
#
# 10) **French Fries: 0.5/10**
#    - French fries are typically high in calories, unhealthy fats, and salt, and they offer very little nutritional benefit. They can contribute to weight gain and increase the risk of heart disease and other health issues.
#
# ### Summary:
# - **Apples** are among the healthiest foods you can consume, ranking just slightly below blueberries but significantly higher than most other common foods.
#
# Trace URL: https://platform.openai.com/logs/trace?trace_id=trace_b55ae2511ab840e7bdf93bc1f2e51833

# %% [markdown]
# ## Short Term Memory

# %%
session = SQLiteSession("conversation_history")

# %%
result = await Runner.run(
    nutrition_agent, "Which is healthier, bananas or lollipop?", session=session
)
print(result.final_output)
# Out:
# Let's compare the healthiness of bananas and lollipops:
#
# 1) **Bananas: 9/10 - Very healthy**
#    - High in dietary fiber, vitamin C, vitamin B6, potassium, and antioxidants.
#    - Low in fat and contain natural sugars that provide a quick energy boost.
#
# 2) **Lollipop: 1/10 - Very unhealthy**
#    - High in refined sugar with little to no nutritional value.
#    - Can contribute to tooth decay and provide empty calories.
#
# Based on this comparison, bananas are significantly healthier than lollipops.

# %%
with trace("Compare with Memory") as t:
    result = await Runner.run(
        nutrition_agent, "Add apples to the comparison", session=session
    )

print(f"Output: {result.final_output}")
print(f"\nTrace URL: https://platform.openai.com/logs/trace?trace_id={t.trace_id}")
# Out:
# Output: Let's add apples to the comparison and rank the three foods by healthiness:
#
# 1) **Bananas: 9/10 - Very healthy**
#    - High in dietary fiber, vitamin C, vitamin B6, potassium, and antioxidants.
#    - Low in fat and contain natural sugars that provide a quick energy boost.
#
# 2) **Apples: 8/10 - Very healthy**
#    - High in dietary fiber, vitamin C, and various antioxidants.
#    - Low in calories and contain natural sugars that provide sustained energy.
#
# 3) **Lollipop: 1/10 - Very unhealthy**
#    - High in refined sugar with little to no nutritional value.
#    - Can contribute to tooth decay and provide empty calories.
#
# Based on this comparison, bananas are the healthiest, followed by apples, and lollipops are the least healthy.
#
# Trace URL: https://platform.openai.com/logs/trace?trace_id=trace_92af0de942c8405e80f92cd9cf4c15b9
